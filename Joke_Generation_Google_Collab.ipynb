# %% [markdown]
# ## Generation For The Sequence2Sequence Models - Roberta2Roberta, Bert2GPT

# %%
#Installing libraries and mounting drive:
# !pip install transformers
# !pip install sentence-transformers==2.0.0
# !pip3 install sentencepiece==0.1.96
# !pip3 install tokenizers
# Out:
# ...
#      |████████████████████████████████| 4.2 MB 6.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 65.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 54.6 MB/s
# ...
#      |████████████████████████████████| 84 kB 2.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 85 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 21.4 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126709 sha256=d25c83669b20ced76b61c1b8fb25f95be3b9b3fd9c0a18a3d4057676ffa433ff
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built sentence-transformers
# ...

# %%
# !ls "/content/drive/MyDrive/Joke Generation Project/WEIGHTED_ROBERTA2ROBERTA_FINAL/checkpoint-24275"
# Out:
# config.json	   rng_state.pth	    tokenizer_config.json  vocab.json
# merges.txt	   scaler.pt		    tokenizer.json
# optimizer.pt	   scheduler.pt		    trainer_state.json
# pytorch_model.bin  special_tokens_map.json  training_args.bin

# %%
from google.colab import drive 
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Joke Generation Project')
from Joke_Generation import TrainedJokeGenerator
bad_word_directory = "/content/drive/MyDrive/Joke Generation Project/Cleaned_Bad_Words.csv"
model_directory = "/content/drive/MyDrive/Joke Generation Project/WEIGHTED_ROBERTA2ROBERTA_FINAL/checkpoint-24275"
# Out:
# Mounted at /content/drive

# %%
# Initializing joke generator and generation parameters
joke_generator = TrainedJokeGenerator(model_directory,bad_word_directory)
# Out:
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# passsed 1
# passed 2
# passed 3

# %%
# The buildup to a joke:
buildup = "How many professors does it take to change a lightbulb?"
top_p = 0.95
top_k = 20
temperature = 1
repetition_penalty = 1
num_sequences = 8
no_repeat_ngram = 3

# %%
punchline_list = joke_generator.generate(buildup,top_p = top_p,num_sequences = num_sequences,no_repeat_ngram_size = no_repeat_ngram,
                        repetition_penalty = repetition_penalty,temperature = temperature)

# %%
#torch.manual_seed(0)
#buildup = "What kind of coffee does an executioner drink?" 
# Decapresso
#buildup = "How many professors does it take to change a lightbulb?"
# "None. That's what students are for."
# 'None. They just sit in the dark and blame the students for it.'

buildup = "How many professors does it take to change a lightbulb?"
